# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Check data-frame

# %%
df = pd.read_csv('KaggleV2-May-2016.csv')
display(df.head())
df.info()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No
# <class 'pandas.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  str
#  3   ScheduledDay    110527 non-null  str
#  4   AppointmentDay  110527 non-null  str
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  str
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  str
# dtypes: float64(1), int64(8), str(5)
# memory usage: 11.8 MB

# %% [markdown]
# # 2. Feature Engineering
# 1. Change column's name
# 2. Convert date to pandas form

# %%
# Changing column's name 
df = df.rename( columns={
    'PatientId' : 'patient_id',
    'AppointmentID': 'appoitment_id',
    'Gender': 'gender',
    'No-show': 'no_show',
    'Handcap': 'handicap',
    'Age': 'age'
    })

# Converting date
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay']).dt.normalize()
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay']).dt.normalize()
df['awaiting_days'] = (df['AppointmentDay'] - df['ScheduledDay']).dt.days


display(df)
# Out:
#           patient_id  appoitment_id gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 00:00:00+00:00
# 1       5.589978e+14        5642503      M 2016-04-29 00:00:00+00:00
# 2       4.262962e+12        5642549      F 2016-04-29 00:00:00+00:00
# 3       8.679512e+11        5642828      F 2016-04-29 00:00:00+00:00
# 4       8.841186e+12        5642494      F 2016-04-29 00:00:00+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572134e+12        5651768      F 2016-05-03 00:00:00+00:00
# 110523  3.596266e+12        5650093      F 2016-05-03 00:00:00+00:00
# 110524  1.557663e+13        5630692      F 2016-04-27 00:00:00+00:00
# 110525  9.213493e+13        5630323      F 2016-04-27 00:00:00+00:00
# 110526  3.775115e+14        5629448      F 2016-04-27 00:00:00+00:00
#
#                   AppointmentDay  age      Neighbourhood  Scholarship  \
# 0      2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1      2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2      2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3      2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4      2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# ...                          ...  ...                ...          ...
# 110522 2016-06-07 00:00:00+00:00   56        MARIA ORTIZ            0
# 110523 2016-06-07 00:00:00+00:00   51        MARIA ORTIZ            0
# 110524 2016-06-07 00:00:00+00:00   21        MARIA ORTIZ            0
# 110525 2016-06-07 00:00:00+00:00   38        MARIA ORTIZ            0
# 110526 2016-06-07 00:00:00+00:00   54        MARIA ORTIZ            0
#
#         Hipertension  Diabetes  Alcoholism  handicap  SMS_received no_show  \
# 0                  1         0           0         0             0      No
# 1                  0         0           0         0             0      No
# 2                  0         0           0         0             0      No
# 3                  0         0           0         0             0      No
# 4                  1         1           0         0             0      No
# ...              ...       ...         ...       ...           ...     ...
# 110522             0         0           0         0             1      No
# 110523             0         0           0         0             1      No
# 110524             0         0           0         0             1      No
# 110525             0         0           0         0             1      No
# 110526             0         0           0         0             1      No
#
#         awaiting_days
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 110522             35
# 110523             35
# 110524             41
# 110525             41
# 110526             41
#
# [110527 rows x 15 columns]

# %% [markdown]
# # 3. Checking validation of data

# %%
df.describe()
# Out:
#          patient_id  appoitment_id            age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism       handicap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       4.000000
#
#         SMS_received  awaiting_days
# count  110527.000000  110527.000000
# mean        0.321026      10.183702
# std         0.466873      15.254996
# min         0.000000      -6.000000
# 25%         0.000000       0.000000
# 50%         0.000000       4.000000
# 75%         1.000000      15.000000
# max         1.000000     179.000000

# %% [markdown]
# Lets look at our columns and understand, something **wrong**.
# 1. Column 'Age' = minimum -1 and maximum 115
# 2. Column 'awaiting_days' = minimum -6
#
# About handicap - there are 4 stages of handicap, so this is the reason, why maximum in cloumn 'handicap' is 4
#
# Lets clean it.

# %%
# Make situation with hadicap clear
df['handicap'].value_counts()
# Out:
# handicap
# 0    108286
# 1      2042
# 2       183
# 3        13
# 4         3
# Name: count, dtype: int64

# %%
df = df[(df['age'] > 0)]
df = df[df['awaiting_days'] >= 0]

df.describe()
# Out:
#          patient_id  appoitment_id            age    Scholarship  \
# count  1.069820e+05   1.069820e+05  106982.000000  106982.000000
# mean   1.472785e+14   5.675434e+06      38.316315       0.101036
# std    2.558181e+14   7.133426e+04      22.466023       0.301377
# min    3.921784e+04   5.030230e+06       1.000000       0.000000
# 25%    4.173345e+12   5.640488e+06      19.000000       0.000000
# 50%    3.172598e+13   5.680744e+06      38.000000       0.000000
# 75%    9.433627e+13   5.725639e+06      56.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism       handicap  \
# count  106982.000000  106982.000000  106982.000000  106982.000000
# mean        0.203782       0.074246       0.031407       0.022957
# std         0.402811       0.262172       0.174416       0.164064
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       4.000000
#
#         SMS_received  awaiting_days
# count  106982.000000  106982.000000
# mean        0.323279      10.167290
# std         0.467730      15.263631
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       4.000000
# 75%         1.000000      14.000000
# max         1.000000     179.000000

# %%
df['no_show'].value_counts()
# Out:
# no_show
# No     85307
# Yes    21675
# Name: count, dtype: int64

# %% [markdown]
# We need to change string on integers, because it will give us more information

# %%
df['no_show_int'] = df['no_show'].map({'Yes': 0, 'No': 1})

df['no_show_int'].value_counts()
# Out:
# no_show_int
# 1    85307
# 0    21675
# Name: count, dtype: int64

# %% [markdown]
# # 4. Is it true that the longer a patient waits for an appointment, the more often they forget to come?
#
# We need to understand whether delays in visits affect attendance.

# %%
wait_analysis = df.groupby('awaiting_days').agg({'patient_id': 'count', 'no_show_int': 'mean'})

wait_analysis.head(10)
# Out:
#                patient_id  no_show_int
# awaiting_days
# 0                   37154     0.953141
# 1                    5028     0.786197
# 2                    6636     0.761302
# 3                    2639     0.763926
# 4                    5212     0.768035
# 5                    3196     0.735294
# 6                    3950     0.753165
# 7                    4785     0.734378
# 8                    2248     0.710854
# 9                    1563     0.725528

# %%
wait_analysis.tail(10)
# Out:
#                patient_id  no_show_int
# awaiting_days
# 133                    11     0.636364
# 139                     1     0.000000
# 142                     8     0.625000
# 146                     1     0.000000
# 151                     1     0.000000
# 155                    10     0.400000
# 162                    11     0.818182
# 169                     8     0.875000
# 176                    16     0.625000
# 179                    10     0.800000

# %% [markdown]
# We can't draw conclusions from the numbers; we need to create a graph for clarity.
# But let's also clarify one thing: we'll exclude data with fewer than 50 patients.

# %%
clean_wait_analysis = wait_analysis[wait_analysis['patient_id'] > 50].reset_index()

display(clean_wait_analysis)
# Out:
#     awaiting_days  patient_id  no_show_int
# 0               0       37154     0.953141
# 1               1        5028     0.786197
# 2               2        6636     0.761302
# 3               3        2639     0.763926
# 4               4        5212     0.768035
# ..            ...         ...          ...
# 71             75          72     0.694444
# 72             76          65     0.692308
# 73             84          54     0.777778
# 74             90          57     0.771930
# 75             91          55     0.781818
#
# [76 rows x 3 columns]

# %%
# lets draw

sns.lineplot(data=clean_wait_analysis, x='awaiting_days', y='no_show_int')
# Out:
# <Axes: xlabel='awaiting_days', ylabel='no_show_int'>

# %%
granicy = [-1, 0, 7, 30, 999]

name = ['same_day', 'week', 'month', 'more_mounth']

df['wait_period'] = pd.cut(df['awaiting_days'], bins=granicy, labels=name)

display(df.head(10))
# Out:
#      patient_id  appoitment_id gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 00:00:00+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 00:00:00+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 00:00:00+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 00:00:00+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 00:00:00+00:00
# 5  9.598513e+13        5626772      F 2016-04-27 00:00:00+00:00
# 6  7.336882e+14        5630279      F 2016-04-27 00:00:00+00:00
# 7  3.449833e+12        5630575      F 2016-04-27 00:00:00+00:00
# 8  5.639473e+13        5638447      F 2016-04-29 00:00:00+00:00
# 9  7.812456e+13        5629123      F 2016-04-27 00:00:00+00:00
#
#              AppointmentDay  age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 5 2016-04-29 00:00:00+00:00   76          REPÚBLICA            0
# 6 2016-04-29 00:00:00+00:00   23         GOIABEIRAS            0
# 7 2016-04-29 00:00:00+00:00   39         GOIABEIRAS            0
# 8 2016-04-29 00:00:00+00:00   21         ANDORINHAS            0
# 9 2016-04-29 00:00:00+00:00   19          CONQUISTA            0
#
#    Hipertension  Diabetes  Alcoholism  handicap  SMS_received no_show  \
# 0             1         0           0         0             0      No
# 1             0         0           0         0             0      No
# 2             0         0           0         0             0      No
# 3             0         0           0         0             0      No
# 4             1         1           0         0             0      No
# 5             1         0           0         0             0      No
# 6             0         0           0         0             0     Yes
# 7             0         0           0         0             0     Yes
# 8             0         0           0         0             0      No
# 9             0         0           0         0             0      No
#
#    awaiting_days  no_show_int wait_period
# 0              0            1    same_day
# 1              0            1    same_day
# 2              0            1    same_day
# 3              0            1    same_day
# 4              0            1    same_day
# 5              2            1        week
# 6              2            0        week
# 7              2            0        week
# 8              0            1    same_day
# 9              2            1        week

# %%
df['wait_period'].value_counts()
# Out:
# wait_period
# same_day       37154
# week           31446
# month          28386
# more_mounth     9996
# Name: count, dtype: int64

# %%
df_wait_period = df.groupby('wait_period').agg({'no_show_int': 'mean'})

display(df_wait_period)
# Out:
#              no_show_int
# wait_period
# same_day        0.953141
# week            0.758856
# month           0.681674
# more_mounth     0.668367

# %%
sns.barplot(data=df_wait_period, x='wait_period', y='no_show_int')
# Out:
# <Axes: xlabel='wait_period', ylabel='no_show_int'>

# %% [markdown]
# We can understand that patients who come every day are much more profitable than those who wait longer.

# %% [markdown]
# # 5. Does sending SMS increase patient retention rates?

# %%
df['SMS_received'].value_counts()
# Out:
# SMS_received
# 0    72397
# 1    34585
# Name: count, dtype: int64

# %%
sms_analysis = df.groupby('SMS_received').agg({'patient_id': 'count', 'no_show_int': 'mean'})
display(sms_analysis)

display(sms_analysis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 sms_analysis = df.groupby('SMS_received').agg[{'patient_id': 'count', 'no_show_int': 'mean'}]
#       2
#       3 display(sms_analysis)
#
# TypeError: 'method' object is not subscriptable
